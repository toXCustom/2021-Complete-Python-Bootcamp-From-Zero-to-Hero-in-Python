# %%
if True:
    print("ITS TRUE!")
# Out:
# ITS TRUE!

# %%
if 3 > 2:
    print("ITS TRUE!")
# Out:
# ITS TRUE!

# %%
hungry = True

if hungry:
    print("Feed me!")
# Out:
# Feed me!

# %%
hungry = True

if hungry:
    print("Feed me!")
else:
    print("Im not hungry")
# Out:
# Feed me!

# %%
hungry = False

if hungry:
    print("Feed me!")
else:
    print("Im not hungry")
# Out:
# Im not hungry

# %%
loc = 'Bank'

if loc == 'Auto Shop':
    print("Cars are cool!")
else:
    print("I don't know much.")
# Out:
# I don't know much.

# %%
loc = 'Bank'

if loc == 'Auto Shop':
    print("Cars are cool!")
elif loc == 'Bank':
    print("Money is cool!")
elif loc == 'Store':
    print("Wel")
